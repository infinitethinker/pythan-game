# %%
import random
def hangman():
    l_of_fruits=["mango","grapes","watermelon"] #list of words
    l_of_games=["boxing","archery","badmintion"]
    final_list=[ l_of_fruits+l_of_games]
    word = random.choice(["mango","grapes","watermelon","boxing","archery","badmintion"])
    if word in l_of_fruits:
        print("<<it's a fruit>> ")
    else:
        print("<<it's a outdoor sport>>")
        
#     print(word)
    turns=10
    guessmade=''
    valid_entry=set('abcedfghijklmnopqrstuvwxyz')  #valid_entrys_for_words
    
   
    while len(word)>0:
        main_word=""
        missed=0
        #to check the input is right or wrong and futher action on it
        for letter in word:
            if letter in guessmade:
                main_word=main_word+letter
            else:
                main_word= main_word+"_ "
                #iff guess is right
        if main_word  == word:
            print(main_word)
            print("you won!!!<.'.>,congrats  superhero ,you save a innocent men")
            break
            
            
        print("guess the word",main_word)    #taking input  for missing word
        guess = input()
        
        if guess in valid_entry:
            guessmade=guessmade+guess
        else:
            print("enter valid character")
            guess=input()
            
        if guess not in word: #creating_image
            turns = turns-1
            
            if turns==9:
                print("9 turns left")
                print("--------------")
            if turns==8:
                print("8 turns left")
                print("----------------")
                print("        O     ")
            if turns==7:
                print("7 turns left")
                print("-----------------")
                print("        O        ")
                print("        |        ")
            if turns==6:
                print("6 turns left")
                print("------------------")
                print("        O         ")
                print("        |         ")
                print("       /          ")
            if turns==5:
                print("5 turns left")
                print("------------------")
                print("        O         ")
                print("        |         ")
                print("       / \        ")
            if turns==4:
                print("4 turns left")
                print("------------------")
                print("       \O         ")
                print("        |         ")
                print("       / \        ")
            if turns==3:
                print("3 turns left")
                print("------------------")
                print("       \O         ")
                print("        |         ")
                print("       / \        ")
            if turns==2:
                print("2 turns left")
                print("------------------")
                print("       \O/        ")
                print("        |         ")
                print("       / \        ")
            if turns==2:
                print("2 turns left")
                print("------------------")
                print("        |       \n")
                print("       \O/        ")
                print("        |         ")
                print("       / \        ")
               
            if turns==1:
                print("hey  be alert only 1 turns left!the inocent men  on his last breath")
                print("------------------")
                print("        |         ")
                print("        |         ")
                print("       \O/        ")
                print("        |         ")
                print("       / \        ")
            if turns== 0:
                print("you killed a inocent guy")
                print("------------------")
                print("        |         ")
                print("        |         ")
                print("        O         ")
                print("       /|\        ")
                print("       | |        ")
                break            
                
                
                
                   
             
             
        





name=input("ENTER YOUR NAME>>>")       #intro_part 
print("welcome",name,"\nlets play")
print("\n Guess the word in less then 10 attempts ")
hangman()
# Out:
# ENTER YOUR NAME>>>sksk
# welcome sksk
# lets play
#
#  Guess the word in less then 10 attempts
# <<it's a fruit>>
# guess the word _ _ _ _ _ _
# q
# 9 turns left
# --------------
# guess the word _ _ _ _ _ _
# r
# guess the word _ r_ _ _ _
# t
# 8 turns left
# ----------------
#         O
# guess the word _ r_ _ _ _
# u
# 7 turns left
# -----------------
#         O
#         |
# guess the word _ r_ _ _ _
# e
# guess the word _ r_ _ e_
# w
# 6 turns left
# ------------------
#         O
#         |
#        /
# guess the word _ r_ _ e_
# w
# 5 turns left
# ------------------
#         O
#         |
#        / \
# guess the word _ r_ _ e_
# y
# 4 turns left
# ------------------
#        \O
#         |
#        / \
# guess the word _ r_ _ e_
# i
# 3 turns left
# ------------------
#        \O
#         |
#        / \
# guess the word _ r_ _ e_
# t
# 2 turns left
# ------------------
#        \O/
#         |
#        / \
# 2 turns left
# ------------------
#         |
#
#        \O/
# ...
